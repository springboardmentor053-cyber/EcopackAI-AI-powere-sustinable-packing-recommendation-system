# %% [markdown]
# ### Step 1: Import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2: Load Raw Datasets

# %%
materials = pd.read_csv("E:\Computer Science\Intern\EcoPackAI\EcopackAI-AI-powere-sustinable-packing-recommendation-system\Dataset\eco_packaging_materials.csv")
products = pd.read_csv("E:\Computer Science\Intern\EcoPackAI\EcopackAI-AI-powere-sustinable-packing-recommendation-system\Dataset\product_categories.csv")

# %%
materials.head()
products.head()
# Out:
#    product_id             product_name     category    sub_category  \
# 0        1001            iPhone 15 Pro  Electronics  Mobile Devices
# 1        1002           MacBook Air M2  Electronics       Computers
# 2        1003     Organic Almonds 500g         Food          Snacks
# 3        1004  Glass Wine Bottle 750ml    Beverages         Alcohol
# 4        1005       Ceramic Dinner Set         Home     Kitchenware
#
#    product_weight_kg dimensions_cm  fragile  food_grade_required  \
# 0               0.19        15x7x1     True                False
# 1               1.24       30x21x1     True                False
# 2               0.50       20x15x5    False                 True
# 3               1.20        30x8x8     True                 True
# 4               4.50      40x40x25     True                 True
#
#    moisture_sensitive  temperature_sensitive preferred_material_type  \
# 0                True                   True             Paper-Based
# 1                True                   True              Pulp-Based
# 2                True                  False     Plant-Based Polymer
# 3               False                   True    Corrugated Cardboard
# 4               False                  False          Mushroom-Based
#
#    max_packaging_cost sustainability_priority
# 0                 2.5                    High
# 1                 5.0                    High
# 2                 1.5                    High
# 3                 3.0                  Medium
# 4                 8.5                    High

# %%
materials.shape
products.shape
# Out:
# (310, 13)

# %%
materials.columns
products.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'sub_category',
#        'product_weight_kg', 'dimensions_cm', 'fragile', 'food_grade_required',
#        'moisture_sensitive', 'temperature_sensitive',
#        'preferred_material_type', 'max_packaging_cost',
#        'sustainability_priority'],
#       dtype='object')

# %%
materials.dtypes
products.dtypes
# Out:
# product_id                   int64
# product_name                object
# category                    object
# sub_category                object
# product_weight_kg          float64
# dimensions_cm               object
# fragile                       bool
# food_grade_required           bool
# moisture_sensitive            bool
# temperature_sensitive         bool
# preferred_material_type     object
# max_packaging_cost         float64
# sustainability_priority     object
# dtype: object

# %%
materials.isnull().sum()
products.isnull().sum()
# Out:
# product_id                 0
# product_name               0
# category                   0
# sub_category               0
# product_weight_kg          0
# dimensions_cm              0
# fragile                    0
# food_grade_required        0
# moisture_sensitive         0
# temperature_sensitive      0
# preferred_material_type    0
# max_packaging_cost         0
# sustainability_priority    0
# dtype: int64

# %%
materials.duplicated().sum()
products.duplicated().sum()
# Out:
# 0

# %%
materials.describe()
# Out:
#        material_id  strength_score  weight_capacity_kg  \
# count   100.000000      100.000000          100.000000
# mean     50.500000        7.006000           21.602000
# std      29.011492        2.127351           28.670676
# min       1.000000        1.000000            0.100000
# 25%      25.750000        5.500000            5.000000
# 50%      50.500000        7.450000           13.000000
# 75%      75.250000        8.800000           25.000000
# max     100.000000        9.900000          200.000000
#
#        biodegradability_score  recyclability_percent  co2_emission_kg  \
# count              100.000000             100.000000       100.000000
# mean                 0.628100              63.700000         0.941000
# std                  0.406278              41.836744         0.654911
# min                  0.000000               0.000000         0.100000
# 25%                  0.100000              15.000000         0.500000
# 50%                  0.850000              90.000000         0.800000
# 75%                  0.960000             100.000000         1.200000
# max                  1.000000             100.000000         3.500000
#
#        cost_per_kg
# count   100.000000
# mean      3.088000
# std       3.136532
# min       0.500000
# 25%       1.500000
# 50%       2.350000
# 75%       3.500000
# max      25.000000
