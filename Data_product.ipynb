# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\HP\Downloads\EcoPackAI\data\processed\product_dataset.csv')
print(df)
# Out:
#      product_category  required_strength  product_weight_kg handling_type  \
# 0    Sports Equipment                 10              18.97    Perishable
# 1                Toys                  3              23.85    Perishable
# 2     Pharmaceuticals                  8              20.09        Liquid
# 3           Cosmetics                  1              19.62         Light
# 4    Sports Equipment                  5              11.06    Perishable
# ..                ...                ...                ...           ...
# 495             Books                 10               6.73         Light
# 496       Electronics                  8              27.48    Perishable
# 497   Medical Devices                  7               7.60         Heavy
# 498         Glassware                  3              10.71    Perishable
# 499        Automotive                  2              12.85        Liquid
#
#     value_category  shipping_type breakage_risk temperature_sensitive  \
# ...

# %%
df = df.drop_duplicates()

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [product_category, required_strength, product_weight_kg, handling_type, value_category, shipping_type, breakage_risk, temperature_sensitive, shelf_life_months]
# Index: []

# %%
df.fillna(0, inplace=True)          

df.dropna(inplace=True)

# %%
df.shape
df.info()
df.columns
df.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   product_category       500 non-null    object
#  1   required_strength      500 non-null    int64
#  2   product_weight_kg      500 non-null    float64
#  3   handling_type          500 non-null    object
#  4   value_category         500 non-null    object
#  5   shipping_type          500 non-null    object
#  6   breakage_risk          500 non-null    object
#  7   temperature_sensitive  500 non-null    object
#  8   shelf_life_months      500 non-null    int64
# dtypes: float64(1), int64(2), object(6)
# memory usage: 35.3+ KB
# product_category          object
# required_strength          int64
# product_weight_kg        float64
# handling_type             object
# value_category            object
# shipping_type             object
# ...

# %%
df.isnull().sum()
df.duplicated().sum
# Out:
# <bound method Series.sum of 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Length: 500, dtype: bool>
