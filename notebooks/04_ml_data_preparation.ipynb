# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
import pandas as pd

df = pd.read_csv("../data/processed/ecopackai_feature_engineered.csv")
df.head()
# Out:
#   material_type product_category  strength  weight_capacity  cost_per_unit  \
# 0         paper      electronics      34.0              8.4           0.12
# 1          jute             home      44.0              8.5           0.28
# 2       bagasse      electronics      39.0              5.3           0.24
# 3       plastic      electronics      72.0             11.4           0.23
# 4         glass      electronics      70.0             12.6           0.54
#
#    biodegradability_score  co2_emission_score  recyclability_percentage  \
# 0                    0.88                0.85                      78.7
# 1                    0.87                1.04                      69.9
# 2                    0.94                0.85                      85.7
# 3                    0.11                9.41                      34.8
# 4                    0.02               20.04                      87.7
#
#    fragility_level shipping_type  co2_impact_index  cost_efficiency_index  \
# ...

# %%
features = [
    "material_type",
    "strength",
    "weight_capacity",
    "biodegradability_score",
    "recyclability_percentage",
    "fragility_level",
    "shipping_type"
]

X = df[features]

# %%
y_cost = df["cost_per_unit"]

# %%
y_co2 = df["co2_impact_index"]

# %%
X = pd.get_dummies(
    X,
    columns=["material_type", "shipping_type"],
    drop_first=True
)

# %%
X_train, X_test, y_cost_train, y_cost_test = train_test_split(
    X, y_cost, test_size=0.2, random_state=42
)

_, _, y_co2_train, y_co2_test = train_test_split(
    X, y_co2, test_size=0.2, random_state=42
)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

num_cols = [
    "strength",
    "weight_capacity",
    "biodegradability_score",
    "recyclability_percentage",
    "fragility_level"
]

X_train[num_cols] = scaler.fit_transform(X_train[num_cols])
X_test[num_cols]  = scaler.transform(X_test[num_cols])

# %%
print("X_train shape:", X_train.shape)
# Out:
# X_train shape: (2080, 12)

# %%
print("X_test shape:", X_test.shape)
# Out:
# X_test shape: (520, 12)

# %%
print("y_cost_train shape:", y_cost_train.shape)
# Out:
# y_cost_train shape: (2080,)

# %%
print("y_cost_test shape:", y_cost_test.shape)
# Out:
# y_cost_test shape: (520,)

# %%
print("y_co2_train shape:", y_co2_train.shape)
# Out:
# y_co2_train shape: (2080,)

# %%
print("y_co2_test shape:", y_co2_test.shape)
# Out:
# y_co2_test shape: (520,)

# %%
print("NaNs in X_train:\n", X_train.isna().sum().sum())
# Out:
# NaNs in X_train:
#  0

# %%
print("NaNs in X_test:\n", X_test.isna().sum().sum())
# Out:
# NaNs in X_test:
#  0

# %%
set(X_train.columns) == set(X_test.columns)
# Out:
# True

# %%
X_train[num_cols].describe()
# Out:
#            strength  weight_capacity  biodegradability_score  \
# count  2.080000e+03     2.080000e+03            2.080000e+03
# mean   4.184687e-17    -5.602356e-16           -6.661338e-17
# std    1.000240e+00     1.000240e+00            1.000240e+00
# min   -1.509900e+00    -1.647559e+00           -1.421917e+00
# 25%   -7.484451e-01    -7.590557e-01           -1.133868e+00
# 50%   -2.212838e-01    -2.122846e-01            6.373256e-01
# 75%    7.158918e-01     6.420454e-01            8.579587e-01
# max    2.531670e+00     3.170862e+00            1.029562e+00
#
#        recyclability_percentage  fragility_level
# count              2.080000e+03     2.080000e+03
# mean               6.251410e-16     1.400589e-16
# std                1.000240e+00     1.000240e+00
# min               -2.498740e+00    -1.083875e+00
# 25%               -3.718289e-01    -1.083875e+00
# 50%                3.056899e-01     2.604660e-01
# 75%                7.407696e-01     2.604660e-01
# ...

# %%
X_train.to_csv("../data/processed/X_train.csv", index=False)
X_test.to_csv("../data/processed/X_test.csv", index=False)

y_cost_train.to_csv("../data/processed/y_cost_train.csv", index=False)
y_cost_test.to_csv("../data/processed/y_cost_test.csv", index=False)

y_co2_train.to_csv("../data/processed/y_co2_train.csv", index=False)
y_co2_test.to_csv("../data/processed/y_co2_test.csv", index=False)
