# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/processed/ecopackai_clean_base.csv")

# %%
print("Loaded shape:", df.shape)
df.head()
# Out:
# Loaded shape: (2600, 10)
#   material_name product_category  strength_rating  weight_capacity_kg  \
# 0         paper      electronics             34.0                 8.4
# 1          jute             home             44.0                 8.5
# 2       bagasse      electronics             39.0                 5.3
# 3       plastic      electronics             72.0                11.4
# 4         glass      electronics             70.0                12.6
#
#    unit_cost_  biodegradability_score  co2_emission_kg  \
# 0        0.12                    0.88             0.85
# 1        0.28                    0.87             1.04
# 2        0.24                    0.94             0.85
# 3        0.23                    0.11             9.41
# 4        0.54                    0.02            20.04
#
#    recyclability_percentage  fragility_level shipping_mode
# 0                      78.7              3.0           air
# 1                      69.9              1.0        ground
# 2                      85.7              3.0           air
# 3                      34.8              3.0           air
# 4                      87.7              3.0           air

# %%
df.columns = (
    df.columns
    .str.strip()
    .str.lower()
    .str.replace(" ", "_")
    .str.replace("(", "")
    .str.replace(")", "")
    .str.replace("%", "percentage")
    .str.replace("$", "")
)

# %%
df = df.rename(columns={
    "material_name": "material_type",
    "product_category": "product_category",
    "strength_rating": "strength",
    "weight_capacity_kg": "weight_capacity",
    "unit_cost_": "cost_per_unit",
    "biodegradability_score": "biodegradability_score",
    "co2_emission_kg": "co2_emission_score",
    "recyclability_percentage": "recyclability_percentage",
    "fragility_level": "fragility_level",
    "shipping_mode": "shipping_type"
})

# %%
expected_cols = [
    "material_type",
    "product_category",
    "strength",
    "weight_capacity",
    "cost_per_unit",
    "biodegradability_score",
    "co2_emission_score",
    "recyclability_percentage",
    "fragility_level",
    "shipping_type"
]

missing_cols = set(expected_cols) - set(df.columns)
assert len(missing_cols) == 0, f"Missing columns: {missing_cols}"

# %%
df["material_type"] = df["material_type"].str.lower().str.strip()
df["product_category"] = df["product_category"].str.lower().str.strip()
df["shipping_type"] = df["shipping_type"].str.lower().str.strip()

# %%
valid_materials = [
    "paper", "plastic", "glass",
    "bamboo", "jute", "bagasse", "metal"
]

valid_categories = [
    "electronics", "food",
    "cosmetics", "pharmaceuticals", "home"
]

df = df[df["material_type"].isin(valid_materials)]
df = df[df["product_category"].isin(valid_categories)]

# %%
numeric_cols = [
    "strength", "weight_capacity",
    "cost_per_unit", "biodegradability_score",
    "co2_emission_score", "recyclability_percentage",
    "fragility_level"
]

df[numeric_cols] = df[numeric_cols].apply(pd.to_numeric, errors="coerce")

# %%
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].median())

# %%
df = df[df["fragility_level"].between(1, 3)]

df = df[df["recyclability_percentage"].between(0, 100)]

df = df[df["biodegradability_score"].between(0, 1)]

# %%
df.loc[df["shipping_type"].isna() & (df["fragility_level"] == 3), "shipping_type"] = "air"
df.loc[df["shipping_type"].isna() & (df["fragility_level"] < 3), "shipping_type"] = "ground"

assert df["shipping_type"].isnull().sum() == 0

# %%
print("Final processed shape:", df.shape)
df.describe(include="all")
# Out:
# Final processed shape: (2600, 10)
#        material_type product_category     strength  weight_capacity  \
# count           2600             2600  2600.000000      2600.000000
# unique             7                5          NaN              NaN
# top          plastic             home          NaN              NaN
# freq             568              545          NaN              NaN
# mean             NaN              NaN    55.962692         9.051962
# std              NaN              NaN    17.213207         2.944545
# min              NaN              NaN    30.000000         4.200000
# 25%              NaN              NaN    43.000000         6.800000
# 50%              NaN              NaN    52.000000         8.400000
# 75%              NaN              NaN    68.000000        10.900000
# max              NaN              NaN    99.000000        19.000000
#
#         cost_per_unit  biodegradability_score  co2_emission_score  \
# count     2600.000000             2600.000000         2600.000000
# unique            NaN                     NaN                 NaN
# top               NaN                     NaN                 NaN
# freq              NaN                     NaN                 NaN
# mean         0.294381                0.575300            6.231327
# std          0.130476                0.409362            6.945922
# min          0.120000                0.000000            0.600000
# 25%          0.200000                0.110000            1.080000
# 50%          0.260000                0.840000            1.480000
# 75%          0.350000                0.930000           12.470000
# max          0.800000                1.000000           24.890000
#
#         recyclability_percentage  fragility_level shipping_type
# count                2600.000000      2600.000000          2600
# unique                       NaN              NaN             2
# top                          NaN              NaN        ground
# freq                         NaN              NaN          2086
# mean                   73.031077         1.802308           NaN
# std                    18.985437         0.742899           NaN
# min                    25.200000         1.000000           NaN
# 25%                    66.000000         1.000000           NaN
# 50%                    78.700000         2.000000           NaN
# 75%                    87.125000         2.000000           NaN
# max                    98.000000         3.000000           NaN

# %%
output_path = "../data/processed/ecopackai_final_base.csv"
df.to_csv(output_path, index=False)

print("Saved:", output_path)
# Out:
# Saved: ../data/processed/ecopackai_final_base.csv
