# %%
import pandas as pd
import numpy as np

df = pd.read_csv(r"C:\Users\HP\Downloads\EcoPackAI\data\processed\eco_materials_dataset.csv")
print(df.head())
# Out:
#               material_name  strength_score  weight_capacity_kg  \
# 0       Palm Leaf Variant 1               4               39.60
# 1     Kraft Paper Variant 2               7               16.25
# 2    Wooden Crate Variant 3              10               15.41
# 3     Kraft Paper Variant 4               6               10.02
# 4  Recycled Paper Variant 5               9               19.63
#
#    biodegradability_score  co2_emission_kg  recyclability_percent  \
# 0                       6             1.75                     44
# 1                       2             5.13                     74
# 2                       4             0.53                     61
# 3                       5             3.01                     62
# 4                       7             4.23                     73
#
#    cost_per_unit_usd moisture_resistance heat_resistance industry_standard  \
# 0               2.11                High          Medium              Food
# ...

# %%
df_ml["eco_score"] = (df_ml["biodegradability_score"] + df_ml["recyclability_percent"]) / 2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df_ml["eco_score"] = (df_ml["biodegradability_score"] + df_ml["recyclability_percent"]) / 2
#
# NameError: name 'df_ml' is not defined

# %%
df_ml = df.drop(columns=["material_name"])

# %%
df_ml["eco_score"] = (df_ml["biodegradability_score"] + df_ml["recyclability_percent"]) / 2

# %%
df_ml["co2_per_strength"] = (
    df_ml["co2_emission_kg"] / df_ml["strength_score"]
)

# %%
df_ml["cost_efficiency"] = (
    df_ml["strength_score"] / df_ml["cost_per_unit_usd"]
)

# %%
df_ml["reuse_efficiency"] = (
    df_ml["reuse_cycles"] / df_ml["cost_per_unit_usd"]
)

# %%
print("Final dataset shape:", df_ml.shape)
print(df_ml.head())
# Out:
# Final dataset shape: (500, 15)
#    strength_score  weight_capacity_kg  biodegradability_score  \
# 0               4               39.60                       6
# 1               7               16.25                       2
# 2              10               15.41                       4
# 3               6               10.02                       5
# 4               9               19.63                       7
#
#    co2_emission_kg  recyclability_percent  cost_per_unit_usd  \
# 0             1.75                     44               2.11
# 1             5.13                     74               0.55
# 2             0.53                     61               0.97
# 3             3.01                     62               2.01
# 4             4.23                     73               1.14
#
#   moisture_resistance heat_resistance industry_standard  reuse_cycles  \
# 0                High          Medium              Food             5
# ...
