# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('c:\\EcopackAI\\Dataset\\material.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111 entries, 0 to 110
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   material_id             111 non-null    int64
#  1   material_name           111 non-null    object
#  2   material_type           111 non-null    object
#  3   strength_score          111 non-null    int64
#  4   weight_capacity_score   111 non-null    int64
#  5   biodegradability_score  111 non-null    int64
#  6   co2_emission_score      111 non-null    int64
#  7   recyclability_percent   111 non-null    int64
# dtypes: int64(6), object(2)
# memory usage: 7.1+ KB

# %%
df.head()
# Out:
#    material_id                       material_name  \
# 0            1     Recycled cardboard / paperboard
# 1            2  Molded pulp (recycled paper fiber)
# 2            3    Kraft paper wraps, paper padding
# 3            4          Starch-based foams/peanuts
# 4            5     Mycelium-based molded packaging
#
#                 material_type  strength_score  weight_capacity_score  \
# 0    Fiber-based (cellulosic)               3                      3
# 1    Fiber-based (cellulosic)               3                      3
# 2                 Fiber-based               2                      2
# 3  Bio-based polymer (starch)               2                      3
# 4         Bio-based composite               3                      3
#
#    biodegradability_score  co2_emission_score  recyclability_percent
# 0                      85                  70                     75
# 1                      85                  70                     70
# ...

# %%
df.tail()
# Out:
#      material_id                    material_name            material_type  \
# 106          107                PHB bottles/trays      Bio-based polyester
# 107          108   Polyhydroxybutyrate composites      Bio-based polyester
# 108          109  Spider silk-inspired synthetics  Bio-based protein mimic
# 109          110                Nettle fiber bags            Natural fiber
# 110          111           Willow bark composites          Lignocellulosic
#
#      strength_score  weight_capacity_score  biodegradability_score  \
# 106               4                      4                      90
# 107               4                      4                      92
# 108               5                      4                      85
# 109               4                      4                      90
# 110               3                      3                      88
#
#      co2_emission_score  recyclability_percent
# 106                  80                     30
# ...

# %%
df.shape
# Out:
# (111, 8)

# %%
df.duplicated().sum()   # count duplicates
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# material_id               0
# material_name             0
# material_type             0
# strength_score            0
# weight_capacity_score     0
# biodegradability_score    0
# co2_emission_score        0
# recyclability_percent     0
# dtype: int64
