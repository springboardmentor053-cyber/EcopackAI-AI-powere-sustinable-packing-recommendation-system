# %%
# !pip install pandas

# %%
import pandas as pd
# Out:
# Running cells with 'Python 3.14.2' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.

# %%
material_df = pd.read_csv('material.csv')
product_df = pd.read_csv('product.csv')
print('Dataset has successfully readed')

# %%
print(material_df.shape)

# %%
material_df.head()

# %%
print(material_df.columns)

# %%
material_df.isna().sum()

# %%
print("Before removing duplicates:", material_df.shape)

material_df.drop_duplicates(inplace=True)

print("After removing duplicates:", material_df.shape)

# %%
material_df.dtypes
